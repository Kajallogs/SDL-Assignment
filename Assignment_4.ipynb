# %% [markdown]
# <a href="https://colab.research.google.com/github/Kajallogs/SDL-Assignment/blob/main/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-faf7671e-a56f-4093-a19c-ce253d5f7590" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-faf7671e-a56f-4093-a19c-ce253d5f7590">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving districtwise_statistics_of_covid_19_cases_in_tn_as_on_01_11_2020.csv to districtwise_statistics_of_covid_19_cases_in_tn_as_on_01_11_2020 (2).csv

# %%
df=pd.read_csv("districtwise_statistics_of_covid_19_cases_in_tn_as_on_01_11_2020.csv")

# %%
df
# Out:
#     S.No  ... Death Cases as on 01.11.2020
# 0      1  ...                           47
# 1      2  ...                          675
# 2      3  ...                         3662
# 3      4  ...                          557
# 4      5  ...                          271
# 5      6  ...                           48
# 6      7  ...                          185
# 7      8  ...                          124
# 8      9  ...                          104
# 9     10  ...                          387
# 10    11  ...                          244
# 11    12  ...                           45
# 12    13  ...                          106
# 13    14  ...                          419
# 14    15  ...                          117
# 15    16  ...                           95
# 16    17  ...                           40
# 17    18  ...                           21
# 18    19  ...                          149
# 19    20  ...                          130
# 20    21  ...                          177
# ...

# %%
missing_values=["NA","NAN","--"]
df=pd.read_csv("districtwise_statistics_of_covid_19_cases_in_tn_as_on_01_11_2020.csv",na_values=missing_values)
print (df['Total Positive Cases as on 01.11.2020'])
print (df['Total Positive Cases as on 01.11.2020'].isnull())
# Out:
# 0       4385.0
# 1      43840.0
# 2     200533.0
# 3      43504.0
# 4      23246.0
# 5       5620.0
# 6       9802.0
# 7      10393.0
# 8      10292.0
# 9      25629.0
# 10     14947.0
# 11      4170.0
# 12      6574.0
# 13     18778.0
# 14      6752.0
# 15      9151.0
# 16      6661.0
# 17      2146.0
# 18     10614.0
# 19      6007.0
# 20     14904.0
# 21     27388.0
# 22      5912.0
# 23      7826.0
# 24     15392.0
# 25     16250.0
# 26     15087.0
# 27     12543.0
# 28     14235.0
# 29      6681.0
# 30     12837.0
# 31         NaN
# 32     17687.0
# 33      9680.0
# 34     17972.0
# 35     13775.0
# 36     15455.0
# 37       925.0
# 38       982.0
# 39       428.0
# Name: Total Positive Cases as on 01.11.2020, dtype: float64
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# ...

# %%
print(df['Discharged Cases as on 01.11.2020'])
print(df['Discharged Cases as on 01.11.2020'].isnull())
# Out:
# 0       4282.0
# 1      42123.0
# 2     189866.0
# 3      41219.0
# 4      22813.0
# 5       5389.0
# 6       9569.0
# 7       9468.0
# 8      10065.0
# 9      24820.0
# 10     14380.0
# 11      3876.0
# 12      6261.0
# 13     17873.0
# 14      6320.0
# 15      8524.0
# 16      6346.0
# 17         NaN
# 18     10296.0
# 19      5824.0
# 20     14522.0
# 21     25541.0
# 22      5662.0
# 23      7645.0
# 24     14899.0
# 25     16003.0
# 26     14501.0
# 27     11948.0
# 28     13869.0
# 29      6321.0
# 30     11683.0
# 31     36420.0
# 32     17120.0
# 33      9261.0
# 34     17276.0
# 35     13358.0
# 36     15106.0
# 37       922.0
# 38       981.0
# 39       428.0
# Name: Discharged Cases as on 01.11.2020, dtype: float64
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# ...

# %%
print (df['Active Cases as on 01.11.2020'])
print (df['Active Cases as on 01.11.2020'].isnull())
# Out:
# 0       56.0
# 1     1042.0
# 2     7005.0
# 3     1728.0
# 4      162.0
# 5      183.0
# 6       48.0
# 7      801.0
# 8      123.0
# 9      422.0
# 10     323.0
# 11     249.0
# 12     207.0
# 13     486.0
# 14     315.0
# 15     532.0
# 16     275.0
# 17      25.0
# 18       NaN
# 19      53.0
# 20     205.0
# 21    1432.0
# 22     124.0
# 23      26.0
# 24     272.0
# 25      54.0
# 26     456.0
# 27     426.0
# 28     158.0
# 29     241.0
# 30     960.0
# 31     981.0
# 32     306.0
# 33     320.0
# 34     389.0
# 35     309.0
# 36     129.0
# 37       2.0
# 38       0.0
# 39       0.0
# Name: Active Cases as on 01.11.2020, dtype: float64
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# ...

# %%
print(df.isnull().sum())
# Out:
# S.No                                     0
# District                                 0
# Total Positive Cases as on 01.11.2020    1
# Discharged Cases as on 01.11.2020        1
# Active Cases as on 01.11.2020            1
# Death Cases as on 01.11.2020             0
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 3

# %%
print (df['Total Positive Cases as on 01.11.2020'])
median = df['Total Positive Cases as on 01.11.2020'].median()
print (median)
# Out:
# 0       4385.0
# 1      43840.0
# 2     200533.0
# 3      43504.0
# 4      23246.0
# 5       5620.0
# 6       9802.0
# 7      10393.0
# 8      10292.0
# 9      25629.0
# 10     14947.0
# 11      4170.0
# 12      6574.0
# 13     18778.0
# 14      6752.0
# 15      9151.0
# 16      6661.0
# 17      2146.0
# 18     10614.0
# 19      6007.0
# 20     14904.0
# 21     27388.0
# 22      5912.0
# 23      7826.0
# 24     15392.0
# 25     16250.0
# 26     15087.0
# 27     12543.0
# 28     14235.0
# 29      6681.0
# 30     12837.0
# 31         NaN
# 32     17687.0
# 33      9680.0
# 34     17972.0
# 35     13775.0
# 36     15455.0
# 37       925.0
# 38       982.0
# 39       428.0
# Name: Total Positive Cases as on 01.11.2020, dtype: float64
# 10614.0

# %%
df['Total Positive Cases as on 01.11.2020'].fillna(median, inplace=True)
print(df['Total Positive Cases as on 01.11.2020'])
# Out:
# 0       4385.0
# 1      43840.0
# 2     200533.0
# 3      43504.0
# 4      23246.0
# 5       5620.0
# 6       9802.0
# 7      10393.0
# 8      10292.0
# 9      25629.0
# 10     14947.0
# 11      4170.0
# 12      6574.0
# 13     18778.0
# 14      6752.0
# 15      9151.0
# 16      6661.0
# 17      2146.0
# 18     10614.0
# 19      6007.0
# 20     14904.0
# 21     27388.0
# 22      5912.0
# 23      7826.0
# 24     15392.0
# 25     16250.0
# 26     15087.0
# 27     12543.0
# 28     14235.0
# 29      6681.0
# 30     12837.0
# 31     10614.0
# 32     17687.0
# 33      9680.0
# 34     17972.0
# 35     13775.0
# 36     15455.0
# 37       925.0
# 38       982.0
# 39       428.0
# Name: Total Positive Cases as on 01.11.2020, dtype: float64

# %%
print (df['Discharged Cases as on 01.11.2020'])
median = df['Discharged Cases as on 01.11.2020'].median()
print (median)
# Out:
# 0       4282.0
# 1      42123.0
# 2     189866.0
# 3      41219.0
# 4      22813.0
# 5       5389.0
# 6       9569.0
# 7       9468.0
# 8      10065.0
# 9      24820.0
# 10     14380.0
# 11      3876.0
# 12      6261.0
# 13     17873.0
# 14      6320.0
# 15      8524.0
# 16      6346.0
# 17         NaN
# 18     10296.0
# 19      5824.0
# 20     14522.0
# 21     25541.0
# 22      5662.0
# 23      7645.0
# 24     14899.0
# 25     16003.0
# 26     14501.0
# 27     11948.0
# 28     13869.0
# 29      6321.0
# 30     11683.0
# 31     36420.0
# 32     17120.0
# 33      9261.0
# 34     17276.0
# 35     13358.0
# 36     15106.0
# 37       922.0
# 38       981.0
# 39       428.0
# Name: Discharged Cases as on 01.11.2020, dtype: float64
# 11683.0

# %%
df['Discharged Cases as on 01.11.2020'].fillna(median, inplace=True)
print(df['Discharged Cases as on 01.11.2020'])
# Out:
# 0       4282.0
# 1      42123.0
# 2     189866.0
# 3      41219.0
# 4      22813.0
# 5       5389.0
# 6       9569.0
# 7       9468.0
# 8      10065.0
# 9      24820.0
# 10     14380.0
# 11      3876.0
# 12      6261.0
# 13     17873.0
# 14      6320.0
# 15      8524.0
# 16      6346.0
# 17     11683.0
# 18     10296.0
# 19      5824.0
# 20     14522.0
# 21     25541.0
# 22      5662.0
# 23      7645.0
# 24     14899.0
# 25     16003.0
# 26     14501.0
# 27     11948.0
# 28     13869.0
# 29      6321.0
# 30     11683.0
# 31     36420.0
# 32     17120.0
# 33      9261.0
# 34     17276.0
# 35     13358.0
# 36     15106.0
# 37       922.0
# 38       981.0
# 39       428.0
# Name: Discharged Cases as on 01.11.2020, dtype: float64

# %%
print (df['Active Cases as on 01.11.2020'])
median = df['Active Cases as on 01.11.2020'].median()
print (median)
# Out:
# 0       56.0
# 1     1042.0
# 2     7005.0
# 3     1728.0
# 4      162.0
# 5      183.0
# 6       48.0
# 7      801.0
# 8      123.0
# 9      422.0
# 10     323.0
# 11     249.0
# 12     207.0
# 13     486.0
# 14     315.0
# 15     532.0
# 16     275.0
# 17      25.0
# 18       NaN
# 19      53.0
# 20     205.0
# 21    1432.0
# 22     124.0
# 23      26.0
# 24     272.0
# 25      54.0
# 26     456.0
# 27     426.0
# 28     158.0
# 29     241.0
# 30     960.0
# 31     981.0
# 32     306.0
# 33     320.0
# 34     389.0
# 35     309.0
# 36     129.0
# 37       2.0
# 38       0.0
# 39       0.0
# Name: Active Cases as on 01.11.2020, dtype: float64
# 272.0

# %%
df['Active Cases as on 01.11.2020'].fillna(median, inplace=True)
print(df['Active Cases as on 01.11.2020'])
# Out:
# 0       56.0
# 1     1042.0
# 2     7005.0
# 3     1728.0
# 4      162.0
# 5      183.0
# 6       48.0
# 7      801.0
# 8      123.0
# 9      422.0
# 10     323.0
# 11     249.0
# 12     207.0
# 13     486.0
# 14     315.0
# 15     532.0
# 16     275.0
# 17      25.0
# 18     272.0
# 19      53.0
# 20     205.0
# 21    1432.0
# 22     124.0
# 23      26.0
# 24     272.0
# 25      54.0
# 26     456.0
# 27     426.0
# 28     158.0
# 29     241.0
# 30     960.0
# 31     981.0
# 32     306.0
# 33     320.0
# 34     389.0
# 35     309.0
# 36     129.0
# 37       2.0
# 38       0.0
# 39       0.0
# Name: Active Cases as on 01.11.2020, dtype: float64

# %%
#Train Dataset
x = df[['Discharged Cases as on 01.11.2020','Active Cases as on 01.11.2020','Death Cases as on 01.11.2020']]
y = df['Total Positive Cases as on 01.11.2020']

# %%
x
# Out:
#     Discharged Cases as on 01.11.2020  ...  Death Cases as on 01.11.2020
# 0                              4282.0  ...                            47
# 1                             42123.0  ...                           675
# 2                            189866.0  ...                          3662
# 3                             41219.0  ...                           557
# 4                             22813.0  ...                           271
# 5                              5389.0  ...                            48
# 6                              9569.0  ...                           185
# 7                              9468.0  ...                           124
# 8                             10065.0  ...                           104
# 9                             24820.0  ...                           387
# 10                            14380.0  ...                           244
# 11                             3876.0  ...                            45
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#     Discharged Cases as on 01.11.2020  ...  Death Cases as on 01.11.2020
# 33                             9261.0  ...                            99
# 15                             8524.0  ...                            95
# 30                            11683.0  ...                           194
# 25                            16003.0  ...                           193
# 11                             3876.0  ...                            45
# 23                             7645.0  ...                           155
# 35                            13358.0  ...                           108
# 2                            189866.0  ...                          3662
# 1                             42123.0  ...                           675
# 7                              9468.0  ...                           124
# 39                              428.0  ...                             0
# 26                            14501.0  ...                           130
# ...

# %%
#Test Dataset
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
clf.predict(x_test)
# Out:
# array([13685.42034251,  1028.39383425, 18463.81695913, 39971.61085914,
#        14021.75133448, 27661.98235804,  3884.75285568, 19737.48126004])

# %%
y_test
# Out:
# 24    15392.0
# 38      982.0
# 4     23246.0
# 3     43504.0
# 10    14947.0
# 21    27388.0
# 0      4385.0
# 13    18778.0
# Name: Total Positive Cases as on 01.11.2020, dtype: float64

# %%
clf.score(x_test,y_test)
# Out:
# 0.9678415226088869

# %%
df.corr()
# Out:
#                                            S.No  ...  Death Cases as on 01.11.2020
# S.No                                   1.000000  ...                     -0.293143
# Total Positive Cases as on 01.11.2020 -0.329299  ...                      0.986105
# Discharged Cases as on 01.11.2020     -0.308563  ...                      0.993875
# Active Cases as on 01.11.2020         -0.298834  ...                      0.970593
# Death Cases as on 01.11.2020          -0.293143  ...                      1.000000
#
# [5 rows x 5 columns]

# %%
df.describe()
# Out:
#             S.No  ...  Death Cases as on 01.11.2020
# count  40.000000  ...                     40.000000
# mean   20.500000  ...                    278.800000
# std    11.690452  ...                    571.917208
# min     1.000000  ...                      0.000000
# 25%    10.750000  ...                    102.750000
# 50%    20.500000  ...                    152.000000
# 75%    30.250000  ...                    248.250000
# max    40.000000  ...                   3662.000000
#
# [8 rows x 5 columns]

# %%
df1=df["Death Cases as on 01.11.2020"]
#print(df1)
max_value=df1.max()
print(max_value)
mean_value=df1.mean()
print(mean_value)
# Out:
# 3662
# 278.8

# %%
new_index = ['a','b','c']
df.reindex(new_index, fill_value=0)
# Out:
#    S.No District  ...  Active Cases as on 01.11.2020  Death Cases as on 01.11.2020
# a     0        0  ...                            0.0                             0
# b     0        0  ...                            0.0                             0
# c     0        0  ...                            0.0                             0
#
# [3 rows x 6 columns]

# %%
Y= df["Discharged Cases as on 01.11.2020"]
X= df["Total Positive Cases as on 01.11.2020"]
plt.scatter(X,Y,label="stars",color="red",marker="1", s=30)
plt.title("Scatter Plot")
plt.xlabel("States")
plt.ylabel("Count")
plt.show()
